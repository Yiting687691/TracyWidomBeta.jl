# %% [markdown]
# ### Part I: Finite-Difference Discretization

# %% [markdown]
# 1. [Error analysis](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/Notebooks/Error%20Analysis%20(FD).ipynb) —— Performs error analysis on the finite-difference discretization.

# %% [markdown]
# ### Part II: Spectral Discretization

# %% [markdown]
# 1. [Error analysis](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/Notebooks/Error%20Analysis%20(Spectral).ipynb) —— Performs error analysis on the spectral discretization.

# %% [markdown]
# ### Part III: Additional Numerical Results

# %% [markdown]
# 1. [Absolute stability region along with eigenvalues](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/Notebooks/Absolute%20stability%20region%20with%20eigenvalues.ipynb) —— Plots of the absolute stability regions along with eigenvalues.

# %% [markdown]
# 2. [Comparison with large random matrices](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/Notebooks/Comparison%20with%20large%20random%20matrices.ipynb) —— Compares the pdf generated by our algorithm with the largest eigenvalue of certain large random matrices.

# %% [markdown]
# 3. [Evolution of the solution](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/Notebooks/Evolution%20of%20the%20solution.ipynb) —— Waterfall plots of the density of the solution and contour plots of the solution.

# %% [markdown]
# 4. [Density of the Tracy-Widom distribution](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/Notebooks/Density%20of%20the%20TW%20distribution.ipynb) —— Waterfall plot of the density of the Tracy-Widom distribution along with a two-dimensional version.

# %% [markdown]
# 5. [Limiting densities of the other eigenvalues](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/Notebooks/Limiting%20densities%20of%20other%20eigenvalues.ipynb) —— Densities of the other eigenvalues.

# %% [markdown]
# ### Part IV: Appendices

# %% [markdown]
# 1. [BDF3](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/Notebooks/BDF3.ipynb) —— The gap of $\Delta x$ causing instability for BDF3.

# %% [markdown]
# 2. [BDF4](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/Notebooks/BDF4.ipynb) —— The gap of $\Delta x$ causing instability for BDF4.

# %% [markdown]
# 3. [BDF5](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/Notebooks/BDF5.ipynb) —— The gap of $\Delta x$ causing instability for BDF5.

# %% [markdown]
# 4. [BDF6](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/Notebooks/BDF6.ipynb) —— The gap of $\Delta x$ causing instability for BDF6.

# %% [markdown]
# 5. [The case when $\beta=\infty$](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/Notebooks/The%20case%20when%20%CE%B2%3DInf.ipynb) —— Contour plot of the solution with respect to $x$ and $\theta$ when $\beta=\infty$.

# %% [markdown]
# 6. [Spectral discretization with DIRK methods](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/Notebooks/Spectral%20discretization%20with%20DIRK%20methods.ipynb) —— Applying some DIRK methods on the spectral discretization.

# %% [markdown]
# 7. [Spectral discretization with adaptive time stepping methods](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/Notebooks/Spectral%20discretization%20with%20adaptive%20time%20stepping%20methods.ipynb) —— Applying some adaptive time stepping methods on the spectral discretization.
