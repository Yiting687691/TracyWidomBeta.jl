# %% [markdown]
# # Computing the Tracy-Widom distribution for arbitrary $\beta>0$

# %% [markdown]
# ## by Yiting Zhang and Tom Trogdon

# %% [markdown]
# The Github repository containing these notebooks is https://github.com/Yiting687691/TracyWidomBeta.jl/tree/main/notebook.

# %% [markdown]
# ## Contents

# %% [markdown]
# - [Introduction](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/notebook/Introduction.ipynb) -- Introduces the background and setup of the problem.

# %% [markdown]
# ## Part I: Finite-Difference Discretization

# %% [markdown]
# 1. [Introduction to finite-difference discretization](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/notebook/Introduction%20(FD).ipynb) -- Introduces how finite-difference discretization is implemented.

# %% [markdown]
# 2. [Error analysis](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/notebook/Error%20Analysis%20(FD).ipynb) -- Performs error analysis on the finite-difference discretization.

# %% [markdown]
# ## Part II: Spectral Discretization

# %% [markdown]
# 1. [Introduction to spectral discretization](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/notebook/Introduction%20(Spectral).ipynb) -- Introduces how spectral discretization is implemented.

# %% [markdown]
# 2. [Error analysis](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/notebook/Error%20Analysis%20(Spectral).ipynb) -- Performs error analysis on the spectral discretization.

# %% [markdown]
# ## Part III: Additional Numerical Results

# %% [markdown]
# 1. [Absolute stability region along with eigenvalues](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/notebook/Absolute%20stability%20region%20with%20eigenvalues.ipynb) -- Plots of the absolute stability regions along with eigenvalues.

# %% [markdown]
# 2. [Comparison with large random matrices](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/notebook/Comparison%20with%20large%20random%20matrices.ipynb) -- Compares the pdf generated by our algorithm with the largest eigenvalue of certain large random matrices.

# %% [markdown]
# 3. [Evolution of the solution](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/notebook/Evolution%20of%20the%20solution.ipynb) -- Waterfall plots of the density of the solution and contour plots of the solution.

# %% [markdown]
# 4. [Density of the Tracy-Widom distribution](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/notebook/Density%20of%20the%20TW%20distribution.ipynb) -- Waterfall plot of the density of the Tracy-Widom distribution along with a two-dimensional version.

# %% [markdown]
# 5. [Limiting densities of the other eigenvalues](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/notebook/Limiting%20densities%20of%20other%20eigenvalues.ipynb) -- Densities of the other eigenvalues.

# %% [markdown]
# ## Part IV: Appendices

# %% [markdown]
# 1. [BDF3](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/notebook/BDF3.ipynb) -- The gap of $\Delta x$ causing instability for BDF3.

# %% [markdown]
# 2. [BDF4](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/notebook/BDF4.ipynb) -- The gap of $\Delta x$ causing instability for BDF4.

# %% [markdown]
# 3. [BDF5](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/notebook/BDF5.ipynb) -- The gap of $\Delta x$ causing instability for BDF5.

# %% [markdown]
# 4. [BDF6](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/notebook/BDF6.ipynb) -- The gap of $\Delta x$ causing instability for BDF6.

# %% [markdown]
# 5. [The case when $\beta=\infty$](https://github.com/Yiting687691/TracyWidomBeta.jl/blob/main/notebook/The%20case%20when%20%CE%B2%3DInf.ipynb) -- Contour plot of the solution with respect to $x$ and $\theta$ when $\beta=\infty$.
